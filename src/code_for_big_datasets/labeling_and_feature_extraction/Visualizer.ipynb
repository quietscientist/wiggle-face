# %%
# imports
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/workspaces/wiggle-face/data/panda_each_video/panda_features_updated_to_be_labeled.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 448436 entries, 0 to 448435
# Data columns (total 33 columns):
#  #   Column                                                Non-Null Count   Dtype
# ---  ------                                                --------------   -----
#  0   infant_id                                             448436 non-null  int64
#  1   date                                                  448436 non-null  int64
#  2   cam                                                   448436 non-null  int64
#  3   frame_id                                              448436 non-null  int64
#  4   right_brow_mean_y                                     448436 non-null  float64
#  5   left_brow_mean_y                                      448436 non-null  float64
#  6   right_eye_distance                                    448436 non-null  float64
#  7   left_eye_distance                                     448436 non-null  float64
#  8   lips_distance                                         448436 non-null  float64
#  9   left_eye_width                                        448436 non-null  float64
#  10  right_eye_width                                       448436 non-null  float64
#  11  left_eyebrow_width                                    448436 non-null  float64
#  12  right_eyebrow_width                                   448436 non-null  float64
#  13  lip_width                                             448436 non-null  float64
#  14  left_eye_upper_corner_left_eyebrow_center_dist        448436 non-null  float64
#  15  right_eye_upper_corner_and_right_eyebrow_center_dist  448436 non-null  float64
#  16  nose_centre_lips_centre_dist                          448436 non-null  float64
#  17  left_eye_lower_corner_lips_left_corner_dist           448436 non-null  float64
#  18  right_eye_lower_corner_lips_right_corner_dist         448436 non-null  float64
#  19  left_eye_upper_corner_lips_left_corner_dist           448436 non-null  float64
#  20  right_eye_upper_corner_lips_right_corner_dist         448436 non-null  float64
#  21  curvature_upper_right_brow                            448436 non-null  float64
#  22  curvature_lower_right_brow                            448436 non-null  float64
#  23  curvature_upper_left_brow                             448436 non-null  float64
#  24  curvature_lower_left_brow                             448436 non-null  float64
#  25  curvature_upper_left_eyelid                           448436 non-null  float64
#  26  curvature_lower_left_eyelid                           448436 non-null  float64
#  27  curvature_upper_right_eyelid                          448436 non-null  float64
#  28  curvature_lower_right_eyelid                          448436 non-null  float64
#  29  curvature_upper_outer_lip                             448436 non-null  float64
#  30  curvature_lower_outer_lip                             448436 non-null  float64
#  31  curvature_upper_inner_lip                             448436 non-null  float64
#  32  curvature_lower_inner_lip                             448436 non-null  float64
# dtypes: float64(29), int64(4)
# memory usage: 112.9 MB

# %%
def remove_outliers(column):
    mean = column.mean()
    std = column.std()
    return column[(column >= mean - 3 * std) & (column <= mean + 3 * std)]

# Define the conditions
conditions = (data['right_brow_mean_y'] >= 0.3) & (data['left_brow_mean_y'] >= 0.3)
eye_width_condition = abs(data['right_eye_width'] - data['left_eye_width']) <= 0.2
eyebrow_width_condition = abs(data['right_eyebrow_width'] - data['left_eyebrow_width']) <= 0.3

# Apply the conditions to filter the rows
filtered_data = data[eye_width_condition & eyebrow_width_condition & conditions].copy()

# Remove outliers for specific columns
filtered_data.loc[:, 'right_eye_width'] = remove_outliers(filtered_data['right_eye_width'])
filtered_data.loc[:, 'left_eye_width'] = remove_outliers(filtered_data['left_eye_width'])
filtered_data.loc[:, 'right_eyebrow_width'] = remove_outliers(filtered_data['right_eyebrow_width'])
filtered_data.loc[:, 'left_eyebrow_width'] = remove_outliers(filtered_data['left_eyebrow_width'])

# Drop rows with NaNs and reset the index
filtered_data.dropna(inplace=True)
filtered_data.reset_index(drop=True, inplace=True)

# Display the DataFrame information
filtered_data.info()

# Display the first few rows of the cleaned DataFrame
print(filtered_data.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230613 entries, 0 to 230612
# Data columns (total 33 columns):
#  #   Column                                                Non-Null Count   Dtype
# ---  ------                                                --------------   -----
#  0   infant_id                                             230613 non-null  int64
#  1   date                                                  230613 non-null  int64
#  2   cam                                                   230613 non-null  int64
#  3   frame_id                                              230613 non-null  int64
#  4   right_brow_mean_y                                     230613 non-null  float64
#  5   left_brow_mean_y                                      230613 non-null  float64
#  6   right_eye_distance                                    230613 non-null  float64
#  7   left_eye_distance                                     230613 non-null  float64
#  8   lips_distance                                         230613 non-null  float64
#  9   left_eye_width                                        230613 non-null  float64
#  10  right_eye_width                                       230613 non-null  float64
#  11  left_eyebrow_width                                    230613 non-null  float64
#  12  right_eyebrow_width                                   230613 non-null  float64
#  13  lip_width                                             230613 non-null  float64
#  14  left_eye_upper_corner_left_eyebrow_center_dist        230613 non-null  float64
#  15  right_eye_upper_corner_and_right_eyebrow_center_dist  230613 non-null  float64
#  16  nose_centre_lips_centre_dist                          230613 non-null  float64
#  17  left_eye_lower_corner_lips_left_corner_dist           230613 non-null  float64
#  18  right_eye_lower_corner_lips_right_corner_dist         230613 non-null  float64
#  19  left_eye_upper_corner_lips_left_corner_dist           230613 non-null  float64
#  20  right_eye_upper_corner_lips_right_corner_dist         230613 non-null  float64
#  21  curvature_upper_right_brow                            230613 non-null  float64
#  22  curvature_lower_right_brow                            230613 non-null  float64
#  23  curvature_upper_left_brow                             230613 non-null  float64
#  24  curvature_lower_left_brow                             230613 non-null  float64
#  25  curvature_upper_left_eyelid                           230613 non-null  float64
#  26  curvature_lower_left_eyelid                           230613 non-null  float64
#  27  curvature_upper_right_eyelid                          230613 non-null  float64
#  28  curvature_lower_right_eyelid                          230613 non-null  float64
#  29  curvature_upper_outer_lip                             230613 non-null  float64
#  30  curvature_lower_outer_lip                             230613 non-null  float64
#  31  curvature_upper_inner_lip                             230613 non-null  float64
#  32  curvature_lower_inner_lip                             230613 non-null  float64
# dtypes: float64(29), int64(4)
# memory usage: 58.1 MB
#    infant_id   date  cam  frame_id  right_brow_mean_y  left_brow_mean_y  \
# 0         28  19233    3       344           0.675700          0.599981
# 1         28  19233    3       345           0.910916          0.835966
# 2         28  19233    3       346           0.908531          0.815992
# 3         28  19233    3       347           0.905686          0.803035
# 4         28  19233    3       348           0.903004          0.836149
#
#    right_eye_distance  left_eye_distance  lips_distance  left_eye_width  ...  \
# 0            0.185727           0.204494       0.011932        0.543713  ...
# 1            0.181797           0.195559       0.011599        0.544486  ...
# 2            0.178147           0.191646       0.011554        0.540807  ...
# 3            0.177924           0.191596       0.009135        0.533945  ...
# 4            0.180817           0.192653       0.008637        0.519658  ...
#
#    curvature_upper_left_brow  curvature_lower_left_brow  \
# 0                   0.969686                   0.499634
# 1                   0.998452                   0.555083
# 2                   0.996743                   0.564500
# 3                   1.107008                   0.520108
# 4                   1.096091                   0.505000
#
#    curvature_upper_left_eyelid  curvature_lower_left_eyelid  \
# 0                     2.214171                     1.257384
# 1                     2.210112                     1.290853
# 2                     2.184071                     1.235044
# 3                     2.197308                     1.245247
# 4                     2.397084                     1.230735
#
#    curvature_upper_right_eyelid  curvature_lower_right_eyelid  \
# 0                      3.066252                      1.482357
# 1                      2.981838                      1.601674
# 2                      2.901092                      1.632863
# 3                      2.897464                      1.572222
# 4                      2.988128                      1.525905
#
#    curvature_upper_outer_lip  curvature_lower_outer_lip  \
# 0                   1.892358                   1.990488
# 1                   1.970029                   2.157748
# 2                   1.845694                   1.652812
# 3                   1.760632                   2.085558
# 4                   1.789232                   1.781074
#
#    curvature_upper_inner_lip  curvature_lower_inner_lip
# 0                   0.834276               4.095382e-15
# 1                   0.737755               7.555149e-15
# 2                   0.941713               4.163905e-15
# 3                   0.659991               1.854047e-01
# 4                   0.554298               2.145972e-01
#
# [5 rows x 33 columns]

# %%
filtered_data.drop(columns=['nose_centre_lips_centre_dist'], inplace=True)
filtered_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230613 entries, 0 to 230612
# Data columns (total 32 columns):
#  #   Column                                                Non-Null Count   Dtype
# ---  ------                                                --------------   -----
#  0   infant_id                                             230613 non-null  int64
#  1   date                                                  230613 non-null  int64
#  2   cam                                                   230613 non-null  int64
#  3   frame_id                                              230613 non-null  int64
#  4   right_brow_mean_y                                     230613 non-null  float64
#  5   left_brow_mean_y                                      230613 non-null  float64
#  6   right_eye_distance                                    230613 non-null  float64
#  7   left_eye_distance                                     230613 non-null  float64
#  8   lips_distance                                         230613 non-null  float64
#  9   left_eye_width                                        230613 non-null  float64
#  10  right_eye_width                                       230613 non-null  float64
#  11  left_eyebrow_width                                    230613 non-null  float64
#  12  right_eyebrow_width                                   230613 non-null  float64
#  13  lip_width                                             230613 non-null  float64
#  14  left_eye_upper_corner_left_eyebrow_center_dist        230613 non-null  float64
#  15  right_eye_upper_corner_and_right_eyebrow_center_dist  230613 non-null  float64
#  16  left_eye_lower_corner_lips_left_corner_dist           230613 non-null  float64
#  17  right_eye_lower_corner_lips_right_corner_dist         230613 non-null  float64
#  18  left_eye_upper_corner_lips_left_corner_dist           230613 non-null  float64
#  19  right_eye_upper_corner_lips_right_corner_dist         230613 non-null  float64
#  20  curvature_upper_right_brow                            230613 non-null  float64
#  21  curvature_lower_right_brow                            230613 non-null  float64
#  22  curvature_upper_left_brow                             230613 non-null  float64
#  23  curvature_lower_left_brow                             230613 non-null  float64
#  24  curvature_upper_left_eyelid                           230613 non-null  float64
#  25  curvature_lower_left_eyelid                           230613 non-null  float64
#  26  curvature_upper_right_eyelid                          230613 non-null  float64
#  27  curvature_lower_right_eyelid                          230613 non-null  float64
#  28  curvature_upper_outer_lip                             230613 non-null  float64
#  29  curvature_lower_outer_lip                             230613 non-null  float64
#  30  curvature_upper_inner_lip                             230613 non-null  float64
#  31  curvature_lower_inner_lip                             230613 non-null  float64
# dtypes: float64(28), int64(4)
# memory usage: 56.3 MB

# %%
import cv2
def process_infant_id(infant_id):
    infant_id_str = str(int(infant_id))
    if len(infant_id_str) == 1:
        return '00' + infant_id_str
    elif len(infant_id_str) == 2:
        return '0' + infant_id_str
    else:
        return infant_id_str[-3:]

# Function to get the frame from the video
def get_frame(video_path, frame_number):
    cap = cv2.VideoCapture(video_path)
    cap.set(cv2.CAP_PROP_POS_FRAMES, frame_number)
    ret, frame = cap.read()
    cap.release()
    if ret:
        return cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    else:
        print(f"Failed to extract frame {frame_number} from {video_path}")
        return None
    
# function to display a selected row
def display_row_panda_1_3(row_index, video_folder):
    if row_index < 0 or row_index >= len(filtered_data):
        print("Invalid row index")
        return
    
    row = filtered_data.iloc[row_index]
    infant_id = process_infant_id(row['infant_id'])
    frame_id = int(row['frame_id'])
    date_id = pd.to_datetime(row['date'], unit='D')
    date_id = date_id.strftime('%Y_%m_%d')
    #emotion = row['cluster']
    cam_id = int(row['cam'])
    
    # video file path
    video_filename = f'r_{date_id}_833180_{infant_id}_cam{cam_id}_vid4.mp4'
    video_path = f'{video_folder}/{video_filename}'
    
    # get the frame
    frame = get_frame(video_path, frame_id)
    
    if frame is not None:
        plt.figure(figsize=(10, 6))
        plt.imshow(frame)
        plt.title(f'Video: {video_filename}, Frame:{frame_id}')
        plt.axis('off')
        plt.show()
    else:
        print(f"Frame {frame_id} could not be retrieved from {video_filename}")

# %%
video_folder_panda_1 = '/workspaces/wiggle-face/data-ioana/PANDA1/r_face_infant_visible/vis'
video_folder_panda_3 = '/workspaces/wiggle-face/data-ioana/PANDA3/face/vis'
display_row_panda_1_3(6100, video_folder_panda_1)

# %%
# Add an empty 'emotion' column to the filtered data
filtered_data['emotion'] = ''
def label_emotion(data, start_index, emotion):
    end_index = min(start_index + 100, len(data))
    data.loc[start_index:end_index, 'emotion'] = emotion
    return data

# %%
# label 'neutral', 'positive', 'negative', 'positive-neutral', 'negative-neutral'
start_index = 1030
emotion = 'negative-neutral'
filtered_data = label_emotion(filtered_data, start_index, emotion)

# %%
filtered_data.to_csv('dataset_for_labeling.csv')
