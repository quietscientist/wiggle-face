# %%
# imports
import os
import json
import pandas as pd
import pandas as pd
import numpy as np
import gc
from scipy.ndimage import median_filter

# %%
# class KeypointsDataset:
#     def __init__(self, json_dir, batch_size=200000):
#         self.json_dir = json_dir
#         self.json_files = [f for f in os.listdir(json_dir) if f.endswith('.json')]
#         self.batch_size = batch_size

#     def keypoint_to_face_part(self, index):
#         if 1 <= index <= 33:
#             return 0  # Do not load in df
#         elif 34 <= index <= 42:
#             return "Right_brow"
#         elif 43 <= index <= 51:
#             return "Left_brow"
#         elif 52 <= index <= 66:
#             if 56 <= index <= 66:
#                 return 0  # Do not load in df
#             return "Nose"
#         elif 67 <= index <= 75:
#             return "Right_Eye"
#         elif 76 <= index <= 84:
#             return "Left_Eye"
#         elif 85 <= index <= 104:
#             return "Mouth"
#         elif index == 105 or index == 106:
#             return 0  # Do not load in df

#     def load_data(self):
#         data = []
#         for json_file in self.json_files:
#             video_id = os.path.splitext(json_file)[0]
#             parts = video_id.split('_')
#             date = '_'.join(parts[1:4])
#             infant_id = parts[5]  
#             camera = parts[6]

#             cam = ord(camera[3:4]) - ord('0')
#             print(f"Processing infant ID: {infant_id} on date: {date}, camera: {cam}")
#             with open(os.path.join(self.json_dir, json_file), 'r') as f:
#                 frames = json.load(f)
#                 for frame_index, frame_data in enumerate(frames):
#                     frame_id = frame_data["frame_id"]
#                     for instance_index, instance in enumerate(frame_data["instances"]):
#                         keypoints = instance["keypoints"]
#                         keypoint_scores = instance["keypoint_scores"]

#                         for idx, (kp, score) in enumerate(zip(keypoints, keypoint_scores)):
#                             face_part = self.keypoint_to_face_part(idx + 1)
#                             if face_part != 0:
#                                 data.append({
#                                     "infant_id": int(infant_id),
#                                     "date": date,
#                                     "cam": cam,
#                                     "frame_id": frame_id,
#                                     "keypoint": tuple(kp),
#                                     "keypoint_score": score,
#                                     "face_part": face_part,
#                                     "keypoint_index": idx + 1    
#                                 })

#                                 if len(data) >= self.batch_size:
#                                     yield data
#                                     data = []
#                                     gc.collect()

#         if data:
#             yield data

# %%
class KeypointsDataset:
    def __init__(self, json_dir, batch_size=200000):
        self.json_dir = json_dir
        self.json_files = [f for f in os.listdir(json_dir) if f.endswith('.json')]
        self.batch_size = batch_size

    def keypoint_to_face_part(self, index):
        if 1 <= index <= 33:
            return 0  # Do not load in df
        elif 34 <= index <= 42:
            return "Right_brow"
        elif 43 <= index <= 51:
            return "Left_brow"
        elif 52 <= index <= 66:
            if 56 <= index <= 66:
                return 0  # Do not load in df
            return "Nose"
        elif 67 <= index <= 75:
            return "Right_Eye"
        elif 76 <= index <= 84:
            return "Left_Eye"
        elif 85 <= index <= 104:
            return "Mouth"
        elif index == 105 or index == 106:
            return 0  # Do not load in df

    def apply_filters(self, df):
        # Apply mean filter across frames for each keypoint index
        df['mean_keypoint_x'] = df.groupby('keypoint_index')['keypoint_x'].rolling(window=3, min_periods=1).mean().reset_index(level=0, drop=True)
        df['mean_keypoint_y'] = df.groupby('keypoint_index')['keypoint_y'].rolling(window=3, min_periods=1).mean().reset_index(level=0, drop=True)
        
        # Apply median filter on the mean-filtered data across frames for each keypoint index
        df['median_keypoint_x'] = df.groupby('keypoint_index')['mean_keypoint_x'].transform(lambda x: median_filter(x, size=3))
        df['median_keypoint_y'] = df.groupby('keypoint_index')['mean_keypoint_y'].transform(lambda x: median_filter(x, size=3))
        
        return df

    def load_data(self):
        data = []
        for json_file in self.json_files:
            video_id = os.path.splitext(json_file)[0]
            parts = video_id.split('_')
            date = '_'.join(parts[1:4])
            infant_id = parts[5]  
            camera = parts[6]

            cam = ord(camera[3:4]) - ord('0')
            print(f"Processing infant ID: {infant_id} on date: {date}, camera: {cam}")
            with open(os.path.join(self.json_dir, json_file), 'r') as f:
                frames = json.load(f)
                frame_data_list = []

                for frame_index, frame_data in enumerate(frames):
                    frame_id = frame_data["frame_id"]
                    for instance_index, instance in enumerate(frame_data["instances"]):
                        keypoints = instance["keypoints"]
                        keypoint_scores = instance["keypoint_scores"]

                        for idx, (kp, score) in enumerate(zip(keypoints, keypoint_scores)):
                            face_part = self.keypoint_to_face_part(idx + 1)
                            if face_part != 0:
                                frame_data_list.append({
                                    "infant_id": int(infant_id),
                                    "date": date,
                                    "cam": cam,
                                    "frame_id": frame_id,
                                    "keypoint": tuple(kp),
                                    "keypoint_score": score,
                                    "face_part": face_part,
                                    "keypoint_index": idx + 1,
                                    "keypoint_x": kp[0],
                                    "keypoint_y": kp[1]
                                })

                # Convert to DataFrame for processing
                df = pd.DataFrame(frame_data_list)

                # Apply filters to smooth the keypoints
                df = self.apply_filters(df)

                # Remove frames with average keypoint confidence under 0.8
                for frame_id, frame_group in df.groupby('frame_id'):
                    if frame_group['keypoint_score'].mean() >= 0.8:
                        for _, row in frame_group.iterrows():
                            data.append({
                                "infant_id": row["infant_id"],
                                "date": row["date"],
                                "cam": row["cam"],
                                "frame_id": row["frame_id"],
                                "keypoint": (row['median_keypoint_x'], row['median_keypoint_y']),
                                "keypoint_score": row["keypoint_score"],
                                "face_part": row["face_part"],
                                "keypoint_index": row["keypoint_index"]
                            })

                            if len(data) >= self.batch_size:
                                yield data
                                data = []
                                gc.collect()

        if data:
            yield data

# %%
# working with PANDA 3/Yt data
json_dir = r'/workspaces/wiggle-face/data-ioana/PANDA3/face/annotations' 
dataset = KeypointsDataset(json_dir)
df = pd.DataFrame()

for batch_data in dataset.load_data():
    batch_df = pd.DataFrame(batch_data)
    df = pd.concat([df, batch_df], ignore_index=True)
# Out:
# Processing infant ID: 218 on date: 2022_11_30, camera: 3
# Processing infant ID: 203 on date: 2022_02_04, camera: 3
# Processing infant ID: 211 on date: 2022_09_08, camera: 3
# Processing infant ID: 228 on date: 2023_07_07, camera: 3
# Processing infant ID: 225 on date: 2022_12_06, camera: 3
# Processing infant ID: 215 on date: 2022_11_04, camera: 3
# Processing infant ID: 201 on date: 2021_10_07, camera: 3
# Processing infant ID: 201 on date: 2021_07_26, camera: 3
# Processing infant ID: 221 on date: 2022_12_19, camera: 3
# Processing infant ID: 207 on date: 2022_02_14, camera: 3
# Processing infant ID: 214 on date: 2022_09_12, camera: 3
# Processing infant ID: 208 on date: 2022_07_11, camera: 3
# Processing infant ID: 215 on date: 2023_03_03, camera: 3
# Processing infant ID: 214 on date: 2022_11_07, camera: 3
# Processing infant ID: 203 on date: 2021_11_05, camera: 3
# Processing infant ID: 202 on date: 2021_08_17, camera: 3
# Processing infant ID: 212 on date: 2022_09_29, camera: 3
# Processing infant ID: 207 on date: 2022_03_18, camera: 3
# Processing infant ID: 222 on date: 2022_12_20, camera: 3
# Processing infant ID: 210 on date: 2022_07_11, camera: 3
# Processing infant ID: 225 on date: 2023_03_09, camera: 3
# Processing infant ID: 219 on date: 2022_11_10, camera: 3
# Processing infant ID: 202 on date: 2021_12_10, camera: 3
# Processing infant ID: 201 on date: 2021_08_19, camera: 3
# Processing infant ID: 216 on date: 2022_12_29, camera: 3
# Processing infant ID: 207 on date: 2022_04_11, camera: 3
# Processing infant ID: 215 on date: 2022_09_30, camera: 3
# Processing infant ID: 211 on date: 2022_07_28, camera: 3
# Processing infant ID: 216 on date: 2023_03_13, camera: 3
# Processing infant ID: 223 on date: 2022_11_10, camera: 3
# Processing infant ID: 204 on date: 2021_12_15, camera: 3
# Processing infant ID: 202 on date: 2021_09_09, camera: 3
# Processing infant ID: 201 on date: 2021_12_16, camera: 3
# Processing infant ID: 221 on date: 2022_11_21, camera: 3
# Processing infant ID: 214 on date: 2023_01_04, camera: 3
# Processing infant ID: 212 on date: 2022_07_28, camera: 3
# Processing infant ID: 214 on date: 2022_10_06, camera: 3
# Processing infant ID: 209 on date: 2022_05_18, camera: 3
# Processing infant ID: 226 on date: 2023_03_14, camera: 3
# Processing infant ID: 203 on date: 2021_09_15, camera: 3
# Processing infant ID: 202 on date: 2022_01_12, camera: 3
# Processing infant ID: 207 on date: 2022_05_20, camera: 3
# Processing infant ID: 215 on date: 2023_01_05, camera: 3
# Processing infant ID: 210 on date: 2022_08_08, camera: 3
# Processing infant ID: 217 on date: 2022_10_11, camera: 3
# Processing infant ID: 222 on date: 2022_11_22, camera: 3
# Processing infant ID: 217 on date: 2023_03_15, camera: 3
# Processing infant ID: 201 on date: 2021_09_16, camera: 3
# Processing infant ID: 204 on date: 2022_01_12, camera: 3
# Processing infant ID: 207 on date: 2022_06_13, camera: 3
# Processing infant ID: 219 on date: 2023_01_05, camera: 3
# Processing infant ID: 202 on date: 2021_10_01, camera: 3
# Processing infant ID: 221 on date: 2022_10_18, camera: 3
# Processing infant ID: 224 on date: 2022_11_22, camera: 3
# Processing infant ID: 219 on date: 2022_12_07, camera: 3
# Processing infant ID: 212 on date: 2022_08_18, camera: 3
# Processing infant ID: 220 on date: 2023_03_17, camera: 3
# Processing infant ID: 211 on date: 2022_07_01, camera: 3
# Processing infant ID: 215 on date: 2022_12_01, camera: 3
# Processing infant ID: 203 on date: 2021_10_06, camera: 3
# Processing infant ID: 217 on date: 2022_12_29, camera: 3
# Processing infant ID: 225 on date: 2023_01_10, camera: 3
# Processing infant ID: 211 on date: 2022_10_05, camera: 3
# Processing infant ID: 214 on date: 2022_12_14, camera: 3
# Processing infant ID: 224 on date: 2023_03_14, camera: 3
# Processing infant ID: 227 on date: 2023_03_17, camera: 3
# Processing infant ID: 220 on date: 2023_01_13, camera: 3
# Processing infant ID: 221 on date: 2023_03_23, camera: 3
# Processing infant ID: 222 on date: 2023_03_23, camera: 3
# Processing infant ID: 224 on date: 2023_01_17, camera: 3
# Processing infant ID: 221 on date: 2023_01_24, camera: 3
# Processing infant ID: 225 on date: 2023_04_07, camera: 3
# Processing infant ID: 215 on date: 2023_02_03, camera: 3
# Processing infant ID: 226 on date: 2023_04_11, camera: 3
# Processing infant ID: 228 on date: 2023_04_25, camera: 3
# Processing infant ID: 219 on date: 2023_02_03, camera: 3
# Processing infant ID: 229 on date: 2023_04_28, camera: 3
# Processing infant ID: 217 on date: 2023_02_08, camera: 3
# Processing infant ID: 227 on date: 2023_05_03, camera: 3
# Processing infant ID: 216 on date: 2023_02_09, camera: 3
# Processing infant ID: 225 on date: 2023_05_11, camera: 3
# Processing infant ID: 225 on date: 2023_02_09, camera: 3
# Processing infant ID: 228 on date: 2023_05_12, camera: 3
# Processing infant ID: 226 on date: 2023_02_16, camera: 3
# Processing infant ID: 230 on date: 2023_05_22, camera: 3
# Processing infant ID: 222 on date: 2023_02_20, camera: 3
# Processing infant ID: 229 on date: 2023_06_21, camera: 3
# Processing infant ID: 221 on date: 2023_02_23, camera: 3
# Processing infant ID: 227 on date: 2023_06_22, camera: 3
# Processing infant ID: 220 on date: 2023_02_24, camera: 3
# Processing infant ID: 232 on date: 2023_07_07, camera: 3
# Processing infant ID: 224 on date: 2023_02_24, camera: 3
# Processing infant ID: 232 on date: 2023_08_11, camera: 3
# Processing infant ID: 227 on date: 2023_02_24, camera: 3
# Processing infant ID: 230 on date: 2023_08_15, camera: 3
# Processing infant ID: 232 on date: 2023_09_06, camera: 3
# Processing infant ID: 233 on date: 2023_08_15, camera: 3
# Processing infant ID: 230 on date: 2023_09_18, camera: 3
# Processing infant ID: 242 on date: 2024_02_23, camera: 3
# Processing infant ID: 233 on date: 2023_09_20, camera: 3
# Processing infant ID: 237 on date: 2024_02_28, camera: 3
# Processing infant ID: 229 on date: 2023_09_27, camera: 3
# Processing infant ID: 239 on date: 2024_02_28, camera: 3
# Processing infant ID: 244 on date: 2024_03_04, camera: 3
# Processing infant ID: 232 on date: 2023_10_03, camera: 3
# Processing infant ID: 235 on date: 2024_03_06, camera: 3
# Processing infant ID: 232 on date: 2023_10_04, camera: 3
# Processing infant ID: 237 on date: 2024_03_06, camera: 3
# Processing infant ID: 230 on date: 2023_10_23, camera: 3
# Processing infant ID: 238 on date: 2024_03_08, camera: 3
# Processing infant ID: 233 on date: 2023_10_25, camera: 3
# Processing infant ID: 234 on date: 2023_11_17, camera: 3
# Processing infant ID: 242 on date: 2024_03_08, camera: 3
# Processing infant ID: 235 on date: 2023_11_17, camera: 3
# Processing infant ID: 243 on date: 2024_03_08, camera: 3
# Processing infant ID: 233 on date: 2023_11_29, camera: 3
# Processing infant ID: 241 on date: 2024_03_19, camera: 3
# Processing infant ID: 232 on date: 2023_12_01, camera: 3
# Processing infant ID: 234 on date: 2024_03_21, camera: 3
# Processing infant ID: 234 on date: 2023_12_13, camera: 3
# Processing infant ID: 243 on date: 2024_03_27, camera: 3
# Processing infant ID: 245 on date: 2024_03_27, camera: 3
# Processing infant ID: 235 on date: 2024_01_03, camera: 3
# Processing infant ID: 239 on date: 2024_04_01, camera: 3
# Processing infant ID: 238 on date: 2024_01_10, camera: 3
# Processing infant ID: 241 on date: 2024_01_22, camera: 3
# Processing infant ID: 244 on date: 2024_04_02, camera: 3
# Processing infant ID: 235 on date: 2024_01_24, camera: 3
# Processing infant ID: 238 on date: 2024_04_05, camera: 3
# Processing infant ID: 242 on date: 2024_04_05, camera: 3
# Processing infant ID: 239 on date: 2024_01_24, camera: 3
# Processing infant ID: 234 on date: 2024_02_07, camera: 3
# Processing infant ID: 241 on date: 2024_04_10, camera: 3
# Processing infant ID: 237 on date: 2024_02_07, camera: 3
# Processing infant ID: 234 on date: 2024_04_17, camera: 3
# Processing infant ID: 238 on date: 2024_02_07, camera: 3
# Processing infant ID: 235 on date: 2024_04_23, camera: 3
# Processing infant ID: 241 on date: 2024_02_12, camera: 3
# Processing infant ID: 245 on date: 2024_04_23, camera: 3
# Processing infant ID: 243 on date: 2024_02_12, camera: 3
# Processing infant ID: 244 on date: 2024_04_24, camera: 3
# Processing infant ID: 235 on date: 2024_02_23, camera: 3
# Processing infant ID: 239 on date: 2024_05_01, camera: 3
# Processing infant ID: 237 on date: 2024_05_07, camera: 3
# Processing infant ID: 243 on date: 2024_05_01, camera: 3
# Processing infant ID: 238 on date: 2024_05_08, camera: 3
# Processing infant ID: 248 on date: 2024_05_10, camera: 4
# Processing infant ID: 228 on date: 2023_06_09, camera: 3
# Processing infant ID: 229 on date: 2023_08_18, camera: 3
# Processing infant ID: 247 on date: 2024_05_15, camera: 3
# Processing infant ID: 228 on date: 2023_09_20, camera: 3
# Processing infant ID: 218 on date: 2022_10_14, camera: 3
# Processing infant ID: 241 on date: 2024_05_16, camera: 3
# Processing infant ID: 244 on date: 2024_05_21, camera: 4
# Processing infant ID: 219 on date: 2022_10_17, camera: 3
# Processing infant ID: 220 on date: 2022_10_18, camera: 3
# Processing infant ID: 245 on date: 2024_05_29, camera: 3
# Processing infant ID: 222 on date: 2022_10_20, camera: 3
# Processing infant ID: 237 on date: 2024_06_06, camera: 3
# Processing infant ID: 223 on date: 2022_10_21, camera: 3
# Processing infant ID: 224 on date: 2022_10_24, camera: 3
# Processing infant ID: 247 on date: 2024_06_06, camera: 3
# Processing infant ID: 218 on date: 2022_11_02, camera: 3
# Processing infant ID: 252 on date: 2024_06_06, camera: 3
# Processing infant ID: 241 on date: 2024_06_07, camera: 4
# Processing infant ID: 216 on date: 2022_11_03, camera: 3
# Processing infant ID: 214 on date: 2023_02_09, camera: 3
# Processing infant ID: 204 on date: 2022_03_16, camera: 3
# Processing infant ID: 230 on date: 2023_06_26, camera: 3
# Processing infant ID: 227 on date: 2023_07_19, camera: 3
# Processing infant ID: 204 on date: 2022_05_17, camera: 3
# Processing infant ID: 229 on date: 2023_07_19, camera: 3
# Processing infant ID: 204 on date: 2022_02_16, camera: 3
# Processing infant ID: 230 on date: 2023_07_24, camera: 3
# Processing infant ID: 212 on date: 2022_05_31, camera: 3
# Processing infant ID: 228 on date: 2023_08_14, camera: 3
# Processing infant ID: 204 on date: 2022_04_19, camera: 3
# Processing infant ID: 201 on date: 2021_11_11, camera: 3
# Processing infant ID: 212 on date: 2022_10_26, camera: 3
# Processing infant ID: 211 on date: 2022_05_12, camera: 3
# Processing infant ID: 207 on date: 2022_07_18, camera: 3
# Processing infant ID: 242 on date: 2024_05_10, camera: 3
# Processing infant ID: 239 on date: 2024_06_07, camera: 3
# Processing infant ID: 234 on date: 2024_01_10, camera: 3
# Processing infant ID: 237 on date: 2024_01_10, camera: 3
# Processing infant ID: 211 on date: 2022_06_02, camera: 3
# Processing infant ID: 229 on date: 2023_05_24, camera: 3

# %%
df.to_csv('preliminary_2.csv', index=False)

# %%
df.head()
# Out:
#    infant_id        date  cam  frame_id  \
# 0        218  2022_11_30    3       367
# 1        218  2022_11_30    3       367
# 2        218  2022_11_30    3       367
# 3        218  2022_11_30    3       367
# 4        218  2022_11_30    3       367
#
#                                   keypoint  keypoint_score   face_part  \
# 0   (979.2205200195312, 329.4839375813802)        0.726164  Right_brow
# 1  (982.0897827148438, 325.85010782877606)        0.693672  Right_brow
# 2  (985.1497802734375, 324.98931884765625)        0.684873  Right_brow
# 3   (988.4008585611979, 324.8057352701823)        0.692774  Right_brow
# 4            (991.2701416015625, 325.1875)        0.695921  Right_brow
#
#    keypoint_index
# 0              34
# 1              35
# 2              36
# 3              37
# 4              38

# %%
df = df.sort_values(by=['infant_id','date','cam','frame_id']).reset_index(drop=True)
print(df)
# Out:
#           infant_id        date  cam  frame_id  \
# 0               201  2021_07_26    3         1
# 1               201  2021_07_26    3         1
# 2               201  2021_07_26    3         1
# 3               201  2021_07_26    3         1
# 4               201  2021_07_26    3         1
# ...             ...         ...  ...       ...
# 29678455        247  2024_06_06    3      7745
# 29678456        247  2024_06_06    3      7745
# 29678457        247  2024_06_06    3      7745
# 29678458        247  2024_06_06    3      7745
# 29678459        247  2024_06_06    3      7745
#
#                                          keypoint  keypoint_score   face_part  \
# 0          (661.7792358398438, 850.8797200520834)        0.815701  Right_brow
# 1          (665.3018493652344, 845.0055338541666)        0.805013  Right_brow
# 2          (670.5080973307291, 840.4264831542969)        0.834134  Right_brow
# 3          (676.5781046549479, 837.4498291015625)        0.844086  Right_brow
# 4            (682.5829874674479, 835.72900390625)        0.809305  Right_brow
# ...                                           ...             ...         ...
# 29678455  (739.8119252522787, 224.35694376627603)        0.884461       Mouth
# 29678456  (745.6254374186198, 226.62339782714844)        0.865226       Mouth
# 29678457  (739.6160430908203, 225.58330790201822)        0.863073       Mouth
# 29678458   (732.0892740885416, 226.1747589111328)        0.855152       Mouth
# 29678459  (724.4999135335287, 229.86469523111978)        0.844080       Mouth
#
#           keypoint_index
# 0                     34
# 1                     35
# 2                     36
# 3                     37
# 4                     38
# ...                  ...
# 29678455             100
# 29678456             101
# 29678457             102
# 29678458             103
# 29678459             104
#
# [29678460 rows x 8 columns]

# %%
## Identify continuous segments that are at least 10 frames long (roughly 1/3 second) 
df = df.sort_values(by=['infant_id', 'date', 'cam', 'keypoint_index', 'frame_id'])
# identify continuous segments for each 'infant_id' and 'keypoint_index'

df['frame_diff'] = df.groupby(['infant_id','date', 'cam', 'keypoint_index'])['frame_id'].diff().fillna(1)
df['block'] = (df['frame_diff'] != 1).cumsum()
blocks = df.groupby(['infant_id','date','cam','keypoint_index', 'block']).filter(lambda x: len(x) >= 10)

# %%
blocks = blocks.drop(columns=['block', 'frame_diff'])
blocks = blocks.rename(columns={"processed_keypoint":"keypoint"})
blocks = blocks[['infant_id', 'date', 'cam', 'frame_id', 'keypoint_index', 'keypoint', 'keypoint_score', 'face_part']]
blocks = blocks.sort_values(by=['infant_id','date','cam','frame_id']).reset_index(drop = True)
blocks.head()
# Out:
#    infant_id        date  cam  frame_id  keypoint_index  \
# 0        201  2021_07_26    3         1              34
# 1        201  2021_07_26    3         1              35
# 2        201  2021_07_26    3         1              36
# 3        201  2021_07_26    3         1              37
# 4        201  2021_07_26    3         1              38
#
#                                  keypoint  keypoint_score   face_part
# 0  (661.7792358398438, 850.8797200520834)        0.815701  Right_brow
# 1  (665.3018493652344, 845.0055338541666)        0.805013  Right_brow
# 2  (670.5080973307291, 840.4264831542969)        0.834134  Right_brow
# 3  (676.5781046549479, 837.4498291015625)        0.844086  Right_brow
# 4    (682.5829874674479, 835.72900390625)        0.809305  Right_brow

# %%
# save as csv files to be processed by "Data_Inspection_Emotion_Analysis"
blocks.to_csv('keypoints_clean_PANDA3_2_dataset.csv', index=False)
print("Dataset saved successfully as keypoints_clean_PANDA3_2_dataset.csv")
# Out:
# Dataset saved successfully as keypoints_clean_PANDA3_2_dataset.csv
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#Old code below

# %%
def process_infant_data(group):
    # Ensure the group is sorted by frame_id
    group = group.sort_values('frame_id')
    
    # Convert 'keypoint' to separate columns for x and y coordinates
    group[['keypoint_x', 'keypoint_y']] = pd.DataFrame(group['keypoint'].tolist(), index=group.index)
    
    # Apply mean filter frame-to-frame
    group['mean_keypoint_x'] = group.groupby('keypoint_index')['keypoint_x'].rolling(window=3, min_periods=1).mean().reset_index(level=0, drop=True)
    group['mean_keypoint_y'] = group.groupby('keypoint_index')['keypoint_y'].rolling(window=3, min_periods=1).mean().reset_index(level=0, drop=True)
    
    # Apply median filter on the mean-filtered data frame-to-frame
    group['median_keypoint_x'] = group.groupby('keypoint_index')['mean_keypoint_x'].transform(lambda x: median_filter(x, size=3))
    group['median_keypoint_y'] = group.groupby('keypoint_index')['mean_keypoint_y'].transform(lambda x: median_filter(x, size=3))
    
    # Combine the median-filtered coordinates back into a tuple
    group['processed_keypoint'] = list(zip(group['median_keypoint_x'], group['median_keypoint_y']))
    
    # Drop intermediate columns
    group.drop(columns=['keypoint_x', 'keypoint_y', 'mean_keypoint_x', 'mean_keypoint_y', 'median_keypoint_x', 'median_keypoint_y'], inplace=True)
    
    return group

# Apply the process_infant_data function to each group
df_processed = df.groupby(['infant_id', 'date', 'cam'], group_keys=False).apply(process_infant_data).reset_index(drop=True)

# %%
print("Original DataFrame:")
df.head(80)
# Out:
# Original DataFrame:
#     infant_id        date  cam  frame_id  \
# 0           3  2021_07_21    3         0
# 1           3  2021_07_21    3         0
# 2           3  2021_07_21    3         0
# 3           3  2021_07_21    3         0
# 4           3  2021_07_21    3         0
# ..        ...         ...  ...       ...
# 75          3  2021_07_21    3         1
# 76          3  2021_07_21    3         1
# 77          3  2021_07_21    3         1
# 78          3  2021_07_21    3         1
# 79          3  2021_07_21    3         1
#
#                                     keypoint  keypoint_score   face_part  \
# 0       (1027.427734375, 229.10992431640625)        0.751885  Right_brow
# 1    (1039.9215087890625, 220.3180389404297)        0.762259  Right_brow
# 2   (1055.6544189453125, 218.92984008789062)        0.720471  Right_brow
# 3   (1070.9244384765625, 221.24349975585938)        0.673808  Right_brow
# 4   (1086.6573486328125, 224.94534301757812)        0.599189  Right_brow
# ..                                       ...             ...         ...
# 75   (1154.517822265625, 219.02101135253906)        0.793231   Left_brow
# 76   (1140.180419921875, 221.79598999023438)        0.744120   Left_brow
# 77  (1125.8431396484375, 225.49594116210938)        0.734699   Left_brow
# 78      (1104.568359375, 237.98330688476562)        0.817636        Nose
# 79      (1104.568359375, 249.08319091796875)        0.864934        Nose
#
#     keypoint_index
# 0               34
# 1               35
# 2               36
# 3               37
# 4               38
# ..             ...
# 75              49
# 76              50
# 77              51
# 78              52
# 79              53
#
# [80 rows x 8 columns]

# %%
print("\nProcessed DataFrame:")
df_processed =  df_processed.drop(columns="keypoint")
df_processed = df_processed.sort_values(by = ["infant_id","date","cam","frame_id", 'keypoint_index']).reset_index(inplace= True)
df_processed.head(80)
# Out:
# Processed DataFrame:
#     index  infant_id        date  cam  frame_id  keypoint_score   face_part  \
# 0       0          3  2021_07_21    3         0        0.751885  Right_brow
# 1      46          3  2021_07_21    3         0        0.762259  Right_brow
# 2      33          3  2021_07_21    3         0        0.720471  Right_brow
# 3      34          3  2021_07_21    3         0        0.673808  Right_brow
# 4      35          3  2021_07_21    3         0        0.599189  Right_brow
# ..    ...        ...         ...  ...       ...             ...         ...
# 75    106          3  2021_07_21    3         1        0.793231   Left_brow
# 76    118          3  2021_07_21    3         1        0.744120   Left_brow
# 77    117          3  2021_07_21    3         1        0.734699   Left_brow
# 78    116          3  2021_07_21    3         1        0.817636        Nose
# 79    115          3  2021_07_21    3         1        0.864934        Nose
#
#     keypoint_index                        processed_keypoint
# 0               34      (1027.427734375, 229.10992431640625)
# 1               35   (1039.9215087890625, 220.3180389404297)
# 2               36  (1055.6544189453125, 218.92984008789062)
# 3               37  (1070.9244384765625, 221.24349975585938)
# 4               38  (1086.6573486328125, 224.94534301757812)
# ..             ...                                       ...
# 75              49    (1154.1356201171875, 219.206787109375)
# 76              50  (1139.7945556640625, 221.98247528076172)
# 77              51  (1125.2222290039062, 225.91474151611328)
# 78              52    (1104.40478515625, 237.90182495117188)
# 79              53    (1104.40478515625, 249.00738525390625)
#
# [80 rows x 9 columns]

# %%
## Find all frames where all keypoints are visible & average confidence above 0.8

grouped = df_processed .groupby(['infant_id', 'date','cam','frame_id']).agg(average_confidence=('keypoint_score', 'mean')).reset_index()
filtered = grouped[grouped['average_confidence'] > 0.8]

# merge back with the original dataframe

filtered_frames = df_processed.merge(filtered, on=['infant_id', 'date','cam','frame_id'], how='inner')
filtered_frames = filtered_frames.sort_values(by=['infant_id', 'date', 'cam','frame_id'])
filtered_frames = filtered_frames.reset_index(drop = True)
print(filtered_frames)
# Out:
#             index  infant_id        date  cam  frame_id  keypoint_score  \
# 0               0          3  2021_07_21    3         0        0.751885
# 1              46          3  2021_07_21    3         0        0.762259
# 2              33          3  2021_07_21    3         0        0.720471
# 3              34          3  2021_07_21    3         0        0.673808
# 4              35          3  2021_07_21    3         0        0.599189
# ...           ...        ...         ...  ...       ...             ...
# 8509915  25711582         86  2024_03_20    3      7487        0.825212
# 8509916  25711583         86  2024_03_20    3      7487        0.749815
# 8509917  25711584         86  2024_03_20    3      7487        0.826427
# 8509918  25711585         86  2024_03_20    3      7487        0.821910
# 8509919  25711586         86  2024_03_20    3      7487        0.852507
#
#           face_part  keypoint_index                        processed_keypoint  \
# 0        Right_brow              34      (1027.427734375, 229.10992431640625)
# 1        Right_brow              35   (1039.9215087890625, 220.3180389404297)
# 2        Right_brow              36  (1055.6544189453125, 218.92984008789062)
# 3        Right_brow              37  (1070.9244384765625, 221.24349975585938)
# 4        Right_brow              38  (1086.6573486328125, 224.94534301757812)
# ...             ...             ...                                       ...
# 8509915       Mouth             100  (1007.0928141276041, 296.56589762369794)
# 8509916       Mouth             101   (1011.8995971679688, 303.8944600423177)
# 8509917       Mouth             102   (1005.2904663085938, 300.6502380371094)
# 8509918       Mouth             103       (996.5185546875, 297.6472981770833)
# 8509919       Mouth             104    (992.4327799479166, 297.0470275878906)
#
#          average_confidence
# 0                  0.811977
# 1                  0.811977
# 2                  0.811977
# 3                  0.811977
# 4                  0.811977
# ...                     ...
# 8509915            0.808204
# 8509916            0.808204
# 8509917            0.808204
# 8509918            0.808204
# 8509919            0.808204
#
# [8509920 rows x 10 columns]

# %%
## Identify continuous segments that are at least 10 frames long (roughly 1/3 second) 
filtered_frames = filtered_frames.sort_values(by=['infant_id', 'date', 'cam', 'keypoint_index', 'frame_id'])
# identify continuous segments for each 'infant_id' and 'keypoint_index'

filtered_frames['frame_diff'] = filtered_frames.groupby(['infant_id','date', 'cam', 'keypoint_index'])['frame_id'].diff().fillna(1)
filtered_frames['block'] = (filtered_frames['frame_diff'] != 1).cumsum()
blocks = filtered_frames.groupby(['infant_id','date','cam','keypoint_index', 'block']).filter(lambda x: len(x) >= 10)
blocks = blocks.drop(columns=['block', 'frame_diff', 'average_confidence'])
blocks = blocks.rename(columns={"processed_keypoint":"keypoint"})
blocks = blocks[['infant_id', 'date', 'cam', 'frame_id', 'keypoint_index', 'keypoint', 'keypoint_score', 'face_part']]
blocks = blocks.sort_values(by=['infant_id','date','cam','frame_id']).reset_index(drop = True)
blocks.head()
# Out:
#    infant_id        date  cam  frame_id  keypoint_index  \
# 0          3  2021_07_21    3         0              34
# 1          3  2021_07_21    3         0              35
# 2          3  2021_07_21    3         0              36
# 3          3  2021_07_21    3         0              37
# 4          3  2021_07_21    3         0              38
#
#                                    keypoint  keypoint_score   face_part
# 0      (1027.427734375, 229.10992431640625)        0.751885  Right_brow
# 1   (1039.9215087890625, 220.3180389404297)        0.762259  Right_brow
# 2  (1055.6544189453125, 218.92984008789062)        0.720471  Right_brow
# 3  (1070.9244384765625, 221.24349975585938)        0.673808  Right_brow
# 4  (1086.6573486328125, 224.94534301757812)        0.599189  Right_brow

# %%
print(blocks)
# Out:
#          infant_id        date  cam  frame_id  keypoint_index  \
# 0                3  2021_07_21    3         0              34
# 1                3  2021_07_21    3         0              35
# 2                3  2021_07_21    3         0              36
# 3                3  2021_07_21    3         0              37
# 4                3  2021_07_21    3         0              38
# ...            ...         ...  ...       ...             ...
# 6242455         83  2024_04_10    3      6887             100
# 6242456         83  2024_04_10    3      6887             101
# 6242457         83  2024_04_10    3      6887             102
# 6242458         83  2024_04_10    3      6887             103
# 6242459         83  2024_04_10    3      6887             104
#
#                                          keypoint  keypoint_score   face_part
# 0            (1027.427734375, 229.10992431640625)        0.751885  Right_brow
# 1         (1039.9215087890625, 220.3180389404297)        0.762259  Right_brow
# 2        (1055.6544189453125, 218.92984008789062)        0.720471  Right_brow
# 3        (1070.9244384765625, 221.24349975585938)        0.673808  Right_brow
# 4        (1086.6573486328125, 224.94534301757812)        0.599189  Right_brow
# ...                                           ...             ...         ...
# 6242455   (1101.3926595052083, 302.6847839355469)        0.871325       Mouth
# 6242456      (1108.4990234375, 303.5752766927083)        0.845414       Mouth
# 6242457   (1101.7375895182292, 305.1812438964844)        0.880751       Mouth
# 6242458  (1092.2136637369792, 307.13128662109375)        0.829116       Mouth
# 6242459  (1080.5155029296875, 308.73655192057294)        0.848547       Mouth
#
# [6242460 rows x 8 columns]

# %%
# save as csv files to be processed by "Data_Inspection_Emotion_Analysis"
blocks.to_csv('keypoints_clean_PANDA1_2_dataset.csv', index=False)
print("Dataset saved successfully as keypoints_clean_PANDA1_2_dataset.csv")
# Out:
# Dataset saved successfully as keypoints_clean_PANDA1_2_dataset.csv
